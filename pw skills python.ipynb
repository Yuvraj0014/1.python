# %%
s="pw skills"

# %%
s[:]
# Out:
# 'pw skills'

# %%
n = int(input("enter the number"))
starting_num = 0
counter=1
while n >=0:
  starting_num=starting_num+counter
  counter=counter+1
print(starting_num)

# %%
import pandas as pd

# %%
pd.read_csv()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 pd.read_csv()
#
# TypeError: read_csv() missing 1 required positional argument: 'filepath_or_buffer'

# %%
d1={'name':'yuvraj','age': 23,'country':'india'}

# %%
d1['age']
# Out:
# 23

# %%
d1.keys()
# Out:
# dict_keys(['name', 'age', 'country'])

# %%
list(d1.keys())[::-1]
# Out:
# ['country', 'age', 'name']

# %%
d
# Out:
#   Cell In[26], line 1
#     d1.'age'
#        ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/yuvra/OneDrive/Desktop/tested.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.dtypes == 'object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.dtypes[df.dtypes == 'object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
df.dtypes[df.dtypes == 'object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df[df.dtypes[df.dtypes == 'object'].index].describe()
# Out:
#                     Name   Sex    Ticket            Cabin Embarked
# count                418   418       418               91      418
# unique               418     2       363               76        3
# top     Kelly, Mr. James  male  PC 17608  B57 B59 B63 B66        S
# freq                   1   266         5                3      270

# %%
df[df.dtypes[df.dtypes == 'float64'].index]
# Out:
#       Age      Fare
# 0    34.5    7.8292
# 1    47.0    7.0000
# 2    62.0    9.6875
# 3    27.0    8.6625
# 4    22.0   12.2875
# ..    ...       ...
# 413   NaN    8.0500
# 414  39.0  108.9000
# 415  38.5    7.2500
# 416   NaN    8.0500
# 417   NaN   22.3583
#
# [418 rows x 2 columns]

# %%
df[df.dtypes[df.dtypes == 'int64'].index]
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch
# 0            892         0       3      0      0
# 1            893         1       3      1      0
# 2            894         0       2      0      0
# 3            895         0       3      0      0
# 4            896         1       3      1      1
# ..           ...       ...     ...    ...    ...
# 413         1305         0       3      0      0
# 414         1306         1       1      0      0
# 415         1307         0       3      0      0
# 416         1308         0       3      0      0
# 417         1309         0       3      1      1
#
# [418 rows x 5 columns]

# %%
df['Ticket']
# Out:
# 0                  330911
# 1                  363272
# 2                  240276
# 3                  315154
# 4                 3101298
#               ...
# 413             A.5. 3236
# 414              PC 17758
# 415    SOTON/O.Q. 3101262
# 416                359309
# 417                  2668
# Name: Ticket, Length: 418, dtype: object

# %%
df[['Ticket','Cabin']]
# Out:
#                  Ticket Cabin
# 0                330911   NaN
# 1                363272   NaN
# 2                240276   NaN
# 3                315154   NaN
# 4               3101298   NaN
# ..                  ...   ...
# 413           A.5. 3236   NaN
# 414            PC 17758  C105
# 415  SOTON/O.Q. 3101262   NaN
# 416              359309   NaN
# 417                2668   NaN
#
# [418 rows x 2 columns]

# %%
df[['Ticket','Cabin']][4:11]
# Out:
#        Ticket Cabin
# 4     3101298   NaN
# 5        7538   NaN
# 6      330972   NaN
# 7      248738   NaN
# 8        2657   NaN
# 9   A/4 48871   NaN
# 10     349220   NaN

# %%
df[['Ticket','Cabin']][4:11:2]
# Out:
#      Ticket Cabin
# 4   3101298   NaN
# 6    330972   NaN
# 8      2657   NaN
# 10   349220   NaN

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df['new_col'] = 0

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
#adding new column
df['new_col2']=df['PassengerId']+df['Pclass']

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked  new_col  new_col2
# 0   330911   7.8292   NaN        Q        0       895
# 1   363272   7.0000   NaN        S        0       896
# 2   240276   9.6875   NaN        Q        0       896
# 3   315154   8.6625   NaN        S        0       898
# ...

# %%
df['Pclass']
# Out:
# 0      3
# 1      3
# 2      2
# 3      3
# 4      3
#       ..
# 413    3
# 414    1
# 415    3
# 416    3
# 417    3
# Name: Pclass, Length: 418, dtype: int64

# %%
pd.Categorical(df['Pclass'])
# Out:
# [3, 3, 2, 3, 3, ..., 3, 1, 3, 3, 3]
# Length: 418
# Categories (3, int64): [1, 2, 3]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked  new_col  new_col2
# 0   330911   7.8292   NaN        Q        0       895
# 1   363272   7.0000   NaN        S        0       896
# 2   240276   9.6875   NaN        Q        0       896
# 3   315154   8.6625   NaN        S        0       898
# ...

# %%
df['Sex']=='male'
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 413     True
# 414    False
# 415     True
# 416     True
# 417     True
# Name: Sex, Length: 418, dtype: bool

# %%
df['Pclass']==3
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 413     True
# 414    False
# 415     True
# 416     True
# 417     True
# Name: Pclass, Length: 418, dtype: bool

# %%
df[(df['Sex']=='male')&(df['Pclass']==3)]
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 0            892         0       3              Kelly, Mr. James  male  34.5
# 3            895         0       3              Wirz, Mr. Albert  male  27.0
# 5            897         0       3    Svensson, Mr. Johan Cervin  male  14.0
# 9            901         0       3       Davies, Mr. John Samuel  male  21.0
# 10           902         0       3              Ilieff, Mr. Ylio  male   NaN
# ..           ...       ...     ...                           ...   ...   ...
# 399         1291         0       3      Conlon, Mr. Thomas Henry  male  31.0
# 413         1305         0       3            Spector, Mr. Woolf  male   NaN
# 415         1307         0       3  Saether, Mr. Simon Sivertsen  male  38.5
# 416         1308         0       3           Ware, Mr. Frederick  male   NaN
# 417         1309         0       3      Peter, Master. Michael J  male   NaN
#
# ...

# %%
data={'key1':[1,2,3,4],
    'key2':[11,22,33,44],
    'key3':['yuvraj','sunny','shiva','priya']
}

# %%
import pandas as pd
df=pd.DataFrame(data)

# %%
df
# Out:
#    key1  key2    key3
# 0     1    11  yuvraj
# 1     2    22   sunny
# 2     3    33   shiva
# 3     4    44   priya

# %%
df.set_index('key1')
# Out:
#       key2    key3
# key1
# 1       11  yuvraj
# 2       22   sunny
# 3       33   shiva
# 4       44   priya

# %%
df
# Out:
#    key1  key2    key3
# 0     1    11  yuvraj
# 1     2    22   sunny
# 2     3    33   shiva
# 3     4    44   priya

# %%
df.set_index('key1',inplace=True)

# %%
df
# Out:
#       key2    key3
# key1
# 1       11  yuvraj
# 2       22   sunny
# 3       33   shiva
# 4       44   priya

# %%
df.reset_index()
# Out:
#    key1  key2    key3
# 0     1    11  yuvraj
# 1     2    22   sunny
# 2     3    33   shiva
# 3     4    44   priya

# %%
data={'key1':[1,2,3,4],
    'key2':[11,22,33,44],
    'key3':['yuvraj','sunny','shiva','priya']
}
df1=pd.DataFrame(data,index=['a','b','c','d'])

# %%
df1
# Out:
#    key1  key2    key3
# a     1    11  yuvraj
# b     2    22   sunny
# c     3    33   shiva
# d     4    44   priya

# %%
df1=df1.reindex(['b','c','d','a'])

# %%
df1
# Out:
#    key1  key2    key3
# b     2    22   sunny
# c     3    33   shiva
# d     4    44   priya
# a     1    11  yuvraj

# %%
for i in df1.iterrows():
    print(i)
# Out:
# ('b', key1        2
# key2       22
# key3    sunny
# Name: b, dtype: object)
# ('c', key1        3
# key2       33
# key3    shiva
# Name: c, dtype: object)
# ('d', key1        4
# key2       44
# key3    priya
# Name: d, dtype: object)
# ('a', key1         1
# key2        11
# key3    yuvraj
# Name: a, dtype: object)

# %%
a=pd.Series([1,5,8,5,6,3,2,8,7,1])

# %%
a.plot()
# Out:
# <Axes: >

# %%
pd.

# %%
##Matplotlib
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.random.rand(50)
y=np.random.rand(50)

# %%
x=[1,2,3,4,5]
y=[4,5,6,7,9]

# %%
plt.plot(x,y,marker='x')
plt.show()

# %%
plt.scatter(x,y,marker='x')
plt.show()

# %%
plt.bar(x,y)
plt.show()

# %%
x=np.random.rand(50)
y=np.random.rand(50)
z=np.random.rand(50)

fig=plt.figure()
ax= fig.add_subplot(projection='3d')
ax.scatter(x,y,z,s=100)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#seaborn

# %%
import seaborn as sns

# %%
iris= sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(x=iris.sepal_length, y= iris.sepal_width)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.displot(iris['sepal_length'])
# Out:
# c:\Users\yuvra\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
tips=sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(x=tips.total_bill,y=tips.tip)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(x=tips.day,y=tips.total_bill,data='tips')
# Out:
# c:\Users\yuvra\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\yuvra\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.catplot(x=tips.smoker,y=tips.tip,data='tips')
# Out:
# c:\Users\yuvra\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\yuvra\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.catplot(x=tips.smoker,y=tips.tip,data='tips')
# Out:
# c:\Users\yuvra\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\yuvra\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Bokeh

# %%
# !pip install bokeh

# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="b9a42b5c-fc56-4bf5-9007-a69400201060">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.plotting import figure,output_file,show

# %%
from bokeh.sampledata.iris import flowers
output_file('test.html')

p=figure(title='test flower')
p.xaxis.axis_label='paltel_length'
p.yaxis.axis_label='paltel_width'
p.circle(flowers['petal_length'],flowers['petal_width'])
show(p)
# Out:
#   <div id="a26db138-4200-49a8-9677-7c857a2ad8da" data-root-id="p1114" style="display: contents;"></div>

# %%
x=[2,3,4,5,6]
y=[3,4,5,6,7]
output_file('line.html')

p=figure(title='line plot')
p.line(x,y,color='red',legend_label='red line',width=20)
show(p)
# Out:
#   <div id="eeab3d14-42a8-4b24-b9e0-1e720fe5b031" data-root-id="p1286" style="display: contents;"></div>

# %%
###Plotly
